# %% [markdown]
# <img style="float: right;" src="https://dm2302files.storage.live.com/y4pP_1KkMzOiZ2WHTAowvxnvX_Ik2vc_h0cV4GsdlOKMTa9kvNnD9TA8E-ey1are6dvQ06fA5GH7ImDw1Ke05RT44Z9QhfqPAKk2PSC9NbGVhtgRPdZb2SU-ln8giolTSGAnwnHTyinah5BPkj0vDgqHxo2H6xEpEXwIhltZXQsLD8/Logo.svg.jpg?psid=1&ck=0&ex=720&width=1360&height=2048" width="300">

# %% [markdown]
# # The Battle of Neighborhoods
#
# <span style="color:gray">*IBM Applied Data Science Capstone - Week 5*</span>

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# ### 1.1 Background

# %% [markdown]
# Evaluating houses is a deeply personal and complex process, impacted by diverse factors ranging from the physical characteristics and local amenities to politic-economic factors. It's important to analyze the situation, research the options, and gather all the necessary information before making an important decision about moving.
#
# Besides the intrinsic features of a property such as the number of beds, baths, square footage, price, age, etc, a  factor that can affect the decision of evaluating houses is the proximity to the things that matter most to them. This may include a workplace, views, parks, schools, community service, residences of relatives and so on.
#
# The same rings true for all who seeks a new place around the world in pursuit of their dreams or in search of a better life.

# %% [markdown]
# ### 1.2 Problem

# %% [markdown]
# Both cities have a large and diverse population of both Toronto and New York, including . Every year hundreds of thousands of immigrants, businessmen and professionals visit, migrate to or settle in these cities for work, livelihood and tourism.
#
# One of my clients lives in Yorkville, Manhattan, New York and she loves her neighborhood. She recieved a great job offer from Toronto, and she decided to move to Toronto in 3 weeks to take up the new opportunity. She wants to find out a neighborhood in Toronto that has similar amenities available near her that she gets in Yorkville.
#
# Therefore the problem is to find neighborhoods that provides similar amenities of its current neighborhood. In this project, Python's data analysis and geospatial analysis packages was used to analyze the whole spectrum of available listings in a market, evaluate and rank properties based on venue category frequency and arrive at a shortlist of neighborhoods in Toronto, similars to Yorkville.

# %% [markdown]
# ### 1.3 Target Audience

# %% [markdown]
# Target audience for this project is anyone who is searching for a new properties in neighborhoods that provides similar amenities of their current neighborhood.

# %% [markdown]
# ## 2. Data

# %% [markdown]
# Housing data for the city of New York was collected from the New York University Libraries <span style="color:blue">[1]</span>. The New York dataset has a total of 5 boroughs and 306 neighborhoods, as well as the latitude and logitude coordinates of each neighborhood.
#
# Housing data for the city of Toronto was scraped from Wikipedia <span style="color:blue">[2]</span> that contains a list of postal codes, boroughs and neighborhoods, with a total of 10 boroughs and 217 neighborhoods.

# %% [markdown]
# ## 3. Methodology

# %% [markdown]
# Firstly, the boroughs and neighborhoods of New York was collected from the New York University Libraries <span style="color:blue">[1]</span>; and postal codes, boroughs and neighborhoods of Toronto was scraped from Wikipedia <span style="color:blue">[2]</span> using Pandas package.
#
# In order to use Foursquare API, the geographical coordinates in the form os latitude and longitude of neighborhoods of Toronto was needed. To do so, the Geocoder package was used to convert address into latitude and longitude.
#
# Next, Foursquare API was used passing the geographical coordinates to get the top 100 venues that are with a radius of 750 meters. Foursquare returns the venue data in JSON format and the venue name, category, latitude and longitude was acquired. Then, each neighborhood was analyzed by grouping the rows by neighborhood and calculating the mean of the frequency of each venue category.
#
#
# Lastly, a shortlist of Toronto neighborhoods was defined by filtering the data with the top 10 most frequent venue category of Yorkville.

# %% [markdown]
# #### Import required libraries

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import geocoder # to get coordinates

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

from tqdm.notebook import tqdm # progress bar library

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

import warnings # warnings library
warnings.filterwarnings("ignore")

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# #### Create New York DataFrame

# %%
# Get New York Dataset
with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)

newyork_data = newyork_data['features']

# Define the DataFrame columns
columns_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

# Instantiate the dataframe
ny_df = pd.DataFrame(columns=columns_names)

for data in newyork_data:
    borough = neighborhood_name = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    ny_df = ny_df.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)

# Drop duplicated neighborhoods
ny_df.drop_duplicates(subset=['Neighborhood'], inplace=True)

ny_df.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %% [markdown]
# #### Create Toronto DataFrame

# %%
# Get tables from the URL and transforme into a DataFrame
tr_df = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')[0] # index 0 is the table of interest

# Rename columns
columns_names = ["PostalCode", "Borough", "Neighborhood"]
tr_df.columns = columns_names

# Drop cells with a borough that is "Not assigned"
tr_df = tr_df[tr_df.Borough != "Not assigned"].reset_index(drop=True)

# Make neighborhood equals the borough if neighborhood is "Not assigned"
for index, row in tr_df.iterrows():
    if row["Neighborhood"] == "Not assigned":
        row["Neighborhood"] = row["Borough"]

# Convert Neighborhood strings to list
tr_df['Neighborhood'] = tr_df.Neighborhood.str.split(',', expand=False)

# Explode Neighborhood list to single rows
tr_df = tr_df.explode('Neighborhood').reset_index(drop=True)

tr_df.head()
# Out:
#   PostalCode           Borough      Neighborhood
# 0        M3A        North York         Parkwoods
# 1        M4A        North York  Victoria Village
# 2        M5A  Downtown Toronto       Regent Park
# 3        M5A  Downtown Toronto      Harbourfront
# 4        M6A        North York    Lawrence Manor

# %%
# Define a function to get coordinates
def get_latlng(neighborhood, state='Toronto', country='Canada'):
    # Initialize your variable to None
    lat_lng_coords = None
    # Loop until you get the coordinates
    while(lat_lng_coords is None):
        g = geocoder.arcgis('{}, {}, {}'.format(neighborhood, state, country))
        lat_lng_coords = g.latlng
    return lat_lng_coords

# %%
# Call the function to get the coordinates, store in a new list using list comprehension
coords = [get_latlng(neighborhood) for neighborhood in tqdm(tr_df["Neighborhood"].tolist(), 'Getting latitudes and longitudes')]

# Create temporary dataframe to populate the coordinates into Latitude and Longitude
df_coords = pd.DataFrame(coords, columns=['Latitude', 'Longitude'])

# Merge the coordinates into the original dataframe
tr_df['Latitude'] = df_coords['Latitude']
tr_df['Longitude'] = df_coords['Longitude']

# Check the neighborhoods and the coordinates
print(tr_df.shape)

tr_df.head()
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Getting latitudes and longitudes', max=217.0, style=Progr…
# (217, 5)
#   PostalCode           Borough      Neighborhood   Latitude  Longitude
# 0        M3A        North York         Parkwoods  43.686575 -79.409993
# 1        M4A        North York  Victoria Village  43.731540 -79.314280
# 2        M5A  Downtown Toronto       Regent Park  43.660690 -79.360310
# 3        M5A  Downtown Toronto      Harbourfront  43.639510 -79.383160
# 4        M6A        North York    Lawrence Manor  43.722940 -79.431160

# %% [markdown]
# #### Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'MDOOB1JIPM2FOIP0BDZ2IJQFB14NTHEVORYGDCITKFFW2GSC' # your Foursquare ID
CLIENT_SECRET = 'X0BEVTOL5WVOY3JKAJNYKU5FD3P0QHY2D0HCYG2MJKEF1KW2' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %% [markdown]
# #### Get the top 100 venues that are within a radius of 500 meters

# %%
def getNearbyVenues(neighborhoods, latitudes, longitudes, radius=750, LIMIT=None):
    
    venues_list=[]
    for neighborhood, lat, lng in tqdm(zip(neighborhoods, latitudes, longitudes), 'Getting data'):
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        try:
            results = requests.get(url).json()["response"]['groups'][0]['items']
        except:
            pass
        # return only relevant information for each nearby venue
        venues_list.append([(
            neighborhood,
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                            'Neighborhood_Latitude', 
                            'Neighborhood_Longitude', 
                            'Venue', 
                            'Venue_Latitude', 
                            'Venue_Longitude', 
                            'Venue_Category']
                  
    
    return(nearby_venues)

# %%
neighborhood = 'Yorkville'

# Get Yorkville venues
ny_venues = getNearbyVenues(neighborhoods=ny_df.loc[ny_df['Neighborhood'] == neighborhood, 'Neighborhood'],
                                 latitudes=ny_df.loc[ny_df['Neighborhood'] == neighborhood, 'Latitude'],
                                 longitudes=ny_df.loc[ny_df['Neighborhood'] == neighborhood, 'Longitude'],
                                 LIMIT=100
                                  )
ny_venues.head()
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Getting data', max=1.0, style=ProgressS…
#   Neighborhood  Neighborhood_Latitude  Neighborhood_Longitude  \
# 0    Yorkville               40.77593              -73.947118
# 1    Yorkville               40.77593              -73.947118
# 2    Yorkville               40.77593              -73.947118
# 3    Yorkville               40.77593              -73.947118
# 4    Yorkville               40.77593              -73.947118
#
#                        Venue  Venue_Latitude  Venue_Longitude  \
# 0        Bagel Bob's on York       40.776459       -73.946972
# 1         Peng's Noodle Folk       40.777258       -73.949110
# 2           Carl Schurz Park       40.775118       -73.943763
# 3  Park East Wines & Spirits       40.776715       -73.946663
# 4                   Shorty's       40.777957       -73.948561
#
#      Venue_Category
# 0        Bagel Shop
# 1  Asian Restaurant
# 2              Park
# 3      Liquor Store
# 4    Sandwich Place

# %%
# Get Toronto venues
toronto_venues = getNearbyVenues(neighborhoods=tr_df['Neighborhood'],
                                 latitudes=tr_df['Latitude'],
                                 longitudes=tr_df['Longitude'],
                                 LIMIT=100
                                  )
toronto_venues.head()
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Getting data', max=1.0, style=ProgressS…
#   Neighborhood  Neighborhood_Latitude  Neighborhood_Longitude  \
# 0    Parkwoods              43.686575              -79.409993
# 1    Parkwoods              43.686575              -79.409993
# 2    Parkwoods              43.686575              -79.409993
# 3    Parkwoods              43.686575              -79.409993
# 4    Parkwoods              43.686575              -79.409993
#
#                              Venue  Venue_Latitude  Venue_Longitude  \
# 0               Aroma Espresso Bar       43.688170       -79.412599
# 1       Sir Winston Churchill Park       43.683732       -79.409881
# 2  Mashu Mashu Mediterranean Grill       43.688297       -79.412563
# 3                     What A Bagel       43.688079       -79.414544
# 4                          Loblaws       43.684188       -79.415485
#
#               Venue_Category
# 0                       Café
# 1                       Park
# 2  Middle Eastern Restaurant
# 3                 Bagel Shop
# 4              Grocery Store

# %% [markdown]
# #### One Hot Encoded DataFrame

# %%
# One hot encoding
ny_onehot = pd.get_dummies(ny_venues[['Venue_Category']], prefix="", prefix_sep="")
toronto_onehot = pd.get_dummies(toronto_venues[['Venue_Category']], prefix="", prefix_sep="")

# Add neighborhood column back to dataframe
ny_onehot['Neighborhood'] = ny_venues['Neighborhood']
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# Move neighborhood column to the first column
ny_fixed_columns = [ny_onehot.columns[-1]] + list(ny_onehot.columns[:-1])
ny_onehot = ny_onehot[ny_fixed_columns]

tr_fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[tr_fixed_columns]

# Group rows by neighborhood and by taking the mean of the frequency of occurrence of each category
ny_grouped = ny_onehot.groupby('Neighborhood').mean().reset_index()
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()

# %% [markdown]
# #### Create a new DataFrame with sorted values

# %%
# Function to sort the venues in descending order
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# Create the new DataFrame and display the top 10 venues for each neighborhood
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# Create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# %%
# Create a new DataFrame
ny_neighborhood_venues_sorted = pd.DataFrame(columns=columns)
ny_neighborhood_venues_sorted['Neighborhood'] = ny_grouped['Neighborhood']

for ind in np.arange(ny_grouped.shape[0]):
    ny_neighborhood_venues_sorted.iloc[ind, 1:] = return_most_common_venues(ny_grouped.iloc[ind, :], num_top_venues)

ny_neighborhood_venues_sorted
# Out:
#   Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0    Yorkville           Coffee Shop                   Gym
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0        Ice Cream Shop    Italian Restaurant         Deli / Bodega
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0           Pizza Place            Bagel Shop             Wine Shop
#
#   9th Most Common Venue 10th Most Common Venue
# 0                   Bar     Mexican Restaurant

# %%
# Create a new DataFrame
tr_neighborhood_venues_sorted = pd.DataFrame(columns=columns)
tr_neighborhood_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    tr_neighborhood_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

tr_neighborhood_venues_sorted
# Out:
#                                        Neighborhood  \
# 0                                          Adelaide
# 1                                   Agincourt North
# 2                                    Albion Gardens
# 3                                     Bathurst Quay
# 4                                  Beaumond Heights
# 5                                 Bloordale Gardens
# 6                   Broadview North (Old East York)
# 7                                       Cabbagetown
# 8                                         Chinatown
# 9                                          Clairlea
# 10                                       Cliffcrest
# 11                                   Cliffside West
# 12                                       Cloverdale
# 13                                        Deer Park
# 14                                  Design Exchange
# 15                               Dovercourt Village
# 16                                  Downsview North
# 17                             East Birchmount Park
# 18                                            Emery
# 19                                 Exhibition Place
# 20                            Forest Hill Road Park
# 21                                   Forest Hill SE
# 22                                      Grange Park
# 23                                          Harbord
# 24                                     Harbourfront
# 25                                Harbourfront West
# 26                                       Henry Farm
# 27                                   Highland Creek
# 28                                       Humber Bay
# 29                                Humber Bay Shores
# 30                            Humber Valley Village
# 31                                       Humbergate
# 32                                          Ionview
# 33                                   Island airport
# 34                                        Islington
# 35                                        Jamestown
# 36                        Keelsdale and Silverthorn
# 37                                             King
# 38                                 King and Spadina
# 39                                 King's Mill Park
# 40                         Kingsway Park South East
# 41                         Kingsway Park South West
# 42                                  L'Amoreaux East
# 43                                  L'Amoreaux West
# 44                                 Lawrence Heights
# 45                              Lawrence Manor East
# 46                                    Lawrence Park
# 47                                      Long Branch
# 48                                  Maple Leaf Park
# 49                                    Markland Wood
# 50                                     Martin Grove
# 51                             Martin Grove Gardens
# 52                                         Maryvale
# 53                                        Mimico NE
# 54                                     Mimico South
# 55                                  Montgomery Road
# 56                                      Morningside
# 57                                     Mount Dennis
# 58                                      Mount Olive
# 59                                      Newtonbrook
# 60                                    North Midtown
# 61                                         Oakridge
# 62                                Old Burnhamthorpe
# 63                                   Old Mill North
# 64                    Ontario Provincial Government
# 65                                           Oriole
# 66                                 Parkdale Village
# 67                                       Port Union
# 68                                 Princess Gardens
# 69                                    Railway Lands
# 70                                        Rathnelly
# 71                                 Richview Gardens
# 72                                        Riverdale
# 73                                     Roncesvalles
# 74                                            Rouge
# 75                            Royal York South East
# 76                            Royal York South West
# 77                                          Ryerson
# 78                          Scarborough Town Centre
# 79                         Scarborough Village West
# 80                                     Silver Hills
# 81                                      Silverstone
# 82    South Central Letter Processing Plant Toronto
# 83                                       South Hill
# 84                                    South Niagara
# 85                                   South of Bloor
# 86                                     St. Phillips
# 87                                     Steeles East
# 88                                         Sullivan
# 89                                  Summerhill East
# 90                                         Sunnylea
# 91                                          Swansea
# 92                                    Tam O'Shanter
# 93                                 The Beaches West
# 94                               The Junction North
# 95                               The Junction South
# 96                               The Queensway East
# 97                               The Queensway West
# 98                                      Thistletown
# 99                                  Toronto Islands
# 100                                         Trinity
# 101                                Underground city
# 102                                   Union Station
# 103                                     Upwood Park
# 104                                  Victoria Hotel
# 105                                       West Hill
# 106                        West Humber - Clairville
# 107                                 Wexford Heights
# 108                                 Willowdale East
# 109                                 Willowdale West
# 110                                  Wilson Heights
# 111                                Woodbine Gardens
# 112                                 York University
# 113                                       Yorkville
# 114                                       Agincourt
# 115                                       Alderwood
# 116                                  Bathurst Manor
# 117                                 Bayview Village
# 118                                    Bedford Park
# 119                                     Berczy Park
# 120                                     Birch Cliff
# 121                                        Brockton
# 122           Business reply mail Processing Centre
# 123                                        CN Tower
# 124                             Caledonia-Fairbanks
# 125           Canada Post Gateway Processing Centre
# 126                                       Cedarbrae
# 127                              Central Bay Street
# 128                                        Christie
# 129                            Church and Wellesley
# 130                                  Clarks Corners
# 131                                       Cliffside
# 132                                  Commerce Court
# 133                                      Davisville
# 134                                Davisville North
# 135                                         Del Ray
# 136                                       Don Mills
# 137                                     Dorset Park
# 138                                       Downsview
# 139                                        Dufferin
# 140                                    East Toronto
# 141                                        Eringate
# 142                                        Fairview
# 143                            First Canadian Place
# 144                        Forest Hill North & West
# 145                                 Garden District
# 146                                       Glencairn
# 147                                     Golden Mile
# 148                                       Guildwood
# 149                               Harbourfront East
# 150                                       High Park
# 151                               Hillcrest Village
# 152                                   Humber Summit
# 153                                       Humberlea
# 154                              Humewood-Cedarvale
# 155                                    India Bazaar
# 156                                Islington Avenue
# 157                                    Kennedy Park
# 158                               Kensington Market
# 159                               Kingsview Village
# 160                                  Lawrence Manor
# 161                                   Lawrence Park
# 162                                         Leaside
# 163                                 Little Portugal
# 164                                         Malvern
# 165                                        Milliken
# 166                                       Mimico NW
# 167                                      Moore Park
# 168                                     New Toronto
# 169                                      North Park
# 170                              North Toronto West
# 171                                       Northwest
# 172                                  Northwood Park
# 173                                  Old Mill South
# 174                                        Parkdale
# 175                                   Parkview Hill
# 176                                       Parkwoods
# 177                                    Queen's Park
# 178                                     Regent Park
# 179                                        Richmond
# 180                                        Rosedale
# 181                                        Roselawn
# 182                                      Rouge Hill
# 183                                       Runnymede
# 184                             Scarborough Village
# 185                                   South Steeles
# 186                                  St. James Town
# 187                                    Steeles West
# 188                                  Stn A PO Boxes
# 189                                 Studio District
# 190                                 Summerhill West
# 191                                       The Annex
# 192                                     The Beaches
# 193                               The Danforth West
# 194                                    The Kingsway
# 195                                Thorncliffe Park
# 196                         Toronto Dominion Centre
# 197                           University of Toronto
# 198                                     Upper Rouge
# 199                                Victoria Village
# 200                                 West Deane Park
# 201                                       Westmount
# 202                                          Weston
# 203                                         Wexford
# 204                                      Willowdale
# 205                                          Woburn
# 206                                Woodbine Heights
# 207                                      York Mills
# 208                                 York Mills West
#
#            1st Most Common Venue          2nd Most Common Venue  \
# 0                    Yoga Studio                            Spa
# 1                           Bank                         Bakery
# 2            Filipino Restaurant           Gym / Fitness Center
# 3                    Coffee Shop                            Gym
# 4              Indian Restaurant           Caribbean Restaurant
# 5              Convenience Store                           Bank
# 6                       Pharmacy                   Intersection
# 7                    Coffee Shop                     Restaurant
# 8                    Coffee Shop  Vegetarian / Vegan Restaurant
# 9                    Coffee Shop              Indian Restaurant
# 10                Ice Cream Shop                    Coffee Shop
# 11                          Park                    Coffee Shop
# 12                Sandwich Place                    Coffee Shop
# 13                   Coffee Shop                           Café
# 14                   Coffee Shop                           Café
# 15                          Café                         Bakery
# 16         Vietnamese Restaurant                    Gas Station
# 17                          Park                            Gym
# 18                   Coffee Shop                   Hockey Field
# 19                   Coffee Shop                    Music Venue
# 20                         Trail                    Coffee Shop
# 21                  Hockey Arena                          Field
# 22                   Coffee Shop                           Café
# 23                          Café                         Bakery
# 24                   Coffee Shop                          Hotel
# 25                   Coffee Shop                          Hotel
# 26                Clothing Store                    Coffee Shop
# 27                Baseball Field                   Tennis Court
# 28                   Coffee Shop                           Bank
# 29                           Bar                 Scenic Lookout
# 30                 Grocery Store                  Shopping Mall
# 31                Baseball Field                  Shopping Mall
# 32                   Coffee Shop                   Intersection
# 33                   Coffee Shop                 Airport Lounge
# 34                      Pharmacy                  Grocery Store
# 35                   Pizza Place                       Gym Pool
# 36                   Pizza Place                         Bakery
# 37                 Train Station                    Coffee Shop
# 38                   Coffee Shop                    Yoga Studio
# 39                          Park                    Pizza Place
# 40                          Park                    Pizza Place
# 41                          Park                    Pizza Place
# 42            Chinese Restaurant           Fast Food Restaurant
# 43            Chinese Restaurant           Fast Food Restaurant
# 44                    Bagel Shop                    Pizza Place
# 45          Fast Food Restaurant                          Diner
# 46                   Coffee Shop             Italian Restaurant
# 47                   Coffee Shop                           Bank
# 48                          Park                    Karaoke Bar
# 49             Convenience Store                           Bank
# 50                          Park                 Clothing Store
# 51                  Liquor Store                  Shopping Mall
# 52                  Soccer Field                    Pizza Place
# 53                          Park              Indian Restaurant
# 54                          Park              Indian Restaurant
# 55                   Coffee Shop                            Pub
# 56                   Coffee Shop                           Park
# 57                   Pizza Place         Furniture / Home Store
# 58                Discount Store                  Shopping Mall
# 59             Korean Restaurant                    Coffee Shop
# 60                   Coffee Shop             Italian Restaurant
# 61                          Park            Filipino Restaurant
# 62                   Gas Station                    Pizza Place
# 63                          Park                          River
# 64                   Coffee Shop                   Burger Joint
# 65                   Coffee Shop             Italian Restaurant
# 66                        Bakery                           Café
# 67                          Park            Japanese Restaurant
# 68                   Wings Joint                   Home Service
# 69                   Coffee Shop                          Hotel
# 70            Italian Restaurant                           Café
# 71                Sandwich Place                 Baseball Field
# 72          Fast Food Restaurant               Greek Restaurant
# 73                   Coffee Shop                         Bakery
# 74                   Gas Station           Fast Food Restaurant
# 75                   Pizza Place                          Plaza
# 76                   Pizza Place                          Plaza
# 77                   Yoga Studio                            Bar
# 78                Clothing Store                     Restaurant
# 79                   Coffee Shop           Fast Food Restaurant
# 80                          Park                    Yoga Studio
# 81                Baseball Field                  Shopping Mall
# 82                   Coffee Shop                          Hotel
# 83                   Coffee Shop                           Park
# 84                           Gym                    Coffee Shop
# 85                Breakfast Spot             Italian Restaurant
# 86                   Coffee Shop                      Gift Shop
# 87                          Farm                    Yoga Studio
# 88                          Park                    Gas Station
# 89                          Park              Indian Restaurant
# 90               Harbor / Marina                           Park
# 91                          Park                    Gas Station
# 92          Fast Food Restaurant                    Pizza Place
# 93                           Pub                 Breakfast Spot
# 94                          Park                           Café
# 95                          Park                           Café
# 96          Fast Food Restaurant                           Bank
# 97          Fast Food Restaurant                           Bank
# 98                 Garden Center                           Park
# 99               Harbor / Marina                     Theme Park
# 100                  Coffee Shop                           Café
# 101                  Coffee Shop                           Café
# 102                        Hotel                    Coffee Shop
# 103                Grocery Store             Mexican Restaurant
# 104                  Coffee Shop                      Gastropub
# 105                         Park              Convenience Store
# 106     Mediterranean Restaurant                          Hotel
# 107           Chinese Restaurant                Badminton Court
# 108                  Wings Joint                     Playground
# 109                         Park                           Road
# 110             Asian Restaurant                    Coffee Shop
# 111         Fast Food Restaurant                       Pharmacy
# 112                  Coffee Shop                           Café
# 113                  Coffee Shop                           Café
# 114           Chinese Restaurant               Asian Restaurant
# 115               Discount Store              Convenience Store
# 116               Baseball Field                    Men's Store
# 117                  Gas Station                     Playground
# 118             Sushi Restaurant             Italian Restaurant
# 119                  Coffee Shop                           Café
# 120                        Diner                    Gas Station
# 121                  Coffee Shop                           Café
# 122                  Coffee Shop                          Hotel
# 123                  Coffee Shop                          Hotel
# 124                         Park                  Grocery Store
# 125                  Coffee Shop                          Hotel
# 126                         Park                     Playground
# 127                  Coffee Shop                 Clothing Store
# 128                Grocery Store                           Café
# 129                  Coffee Shop            Japanese Restaurant
# 130                  Coffee Shop          Vietnamese Restaurant
# 131                         Park                    Coffee Shop
# 132                  Coffee Shop                           Café
# 133                  Coffee Shop                   Dessert Shop
# 134                  Coffee Shop                   Dessert Shop
# 135        Portuguese Restaurant                    Gas Station
# 136                         Park                   Liquor Store
# 137       Furniture / Home Store                     Restaurant
# 138        Vietnamese Restaurant                    Gas Station
# 139                         Park            Japanese Restaurant
# 140                  Coffee Shop                           Café
# 141  Eastern European Restaurant                    Coffee Shop
# 142             Greek Restaurant                    Coffee Shop
# 143                  Coffee Shop                           Café
# 144                         Café                    Coffee Shop
# 145                  Coffee Shop            Japanese Restaurant
# 146                  Pizza Place                  Grocery Store
# 147          Sporting Goods Shop             Chinese Restaurant
# 148               Baseball Field                           Park
# 149                  Coffee Shop                          Hotel
# 150                       Bakery                           Café
# 151                         Park             Chinese Restaurant
# 152                 Home Service                   Skating Rink
# 153             Storage Facility                    Gas Station
# 154                 Hockey Arena              Convenience Store
# 155            Indian Restaurant           Caribbean Restaurant
# 156                     Pharmacy                  Grocery Store
# 157            Convenience Store                     Hobby Shop
# 158                          Bar                           Café
# 159               Hardware Store      Middle Eastern Restaurant
# 160                   Bagel Shop                           Park
# 161                  Coffee Shop             Italian Restaurant
# 162            Indian Restaurant                       Pharmacy
# 163                          Bar                           Café
# 164                  Pizza Place           Fast Food Restaurant
# 165           Chinese Restaurant                       Pharmacy
# 166                         Park              Indian Restaurant
# 167    Middle Eastern Restaurant                    Coffee Shop
# 168           Mexican Restaurant                           Café
# 169                Women's Store         Furniture / Home Store
# 170                  Coffee Shop                           Café
# 171                         Café                    Coffee Shop
# 172                         Park                     Playground
# 173                         Park                          River
# 174                       Bakery    Eastern European Restaurant
# 175                     Pharmacy                    Pizza Place
# 176                         Park                           Café
# 177                  Coffee Shop                           Café
# 178                  Coffee Shop                           Park
# 179                  Coffee Shop                           Café
# 180           Italian Restaurant                            Spa
# 181         Caribbean Restaurant                    Pizza Place
# 182                     Pharmacy                    Supermarket
# 183                  Gas Station                    Coffee Shop
# 184                  Coffee Shop           Fast Food Restaurant
# 185                         Farm                    Yoga Studio
# 186                  Coffee Shop                           Café
# 187                  Karaoke Bar                    Gas Station
# 188                  Coffee Shop                          Hotel
# 189             Business Service                    Yoga Studio
# 190                         Park              Indian Restaurant
# 191            Korean Restaurant                           Café
# 192                          Pub                 Breakfast Spot
# 193                  Coffee Shop                  Grocery Store
# 194                  Coffee Shop                           Bank
# 195            Indian Restaurant                    Coffee Shop
# 196                        Hotel                    Coffee Shop
# 197                   Restaurant             Italian Restaurant
# 198                  Gas Station                 Farmers Market
# 199              Thai Restaurant              French Restaurant
# 200                     Pharmacy                           Park
# 201           Italian Restaurant       Mediterranean Restaurant
# 202                  Coffee Shop                  Train Station
# 203                  Pizza Place                   Burger Joint
# 204                         Park                     Playground
# 205                  Coffee Shop          Vietnamese Restaurant
# 206                  Coffee Shop                 Sandwich Place
# 207                      Butcher                    Coffee Shop
# 208                      Butcher                    Coffee Shop
#
#              3rd Most Common Venue                     4th Most Common Venue  \
# 0                      Coffee Shop                               Pizza Place
# 1                      Pizza Place                                      Park
# 2                             Bank                               Gas Station
# 3                             Park                                      Café
# 4                      Supermarket                               Pizza Place
# 5                   Discount Store                      Fast Food Restaurant
# 6                 Greek Restaurant                                   Theater
# 7                  Thai Restaurant                                     Diner
# 8               Mexican Restaurant                                      Café
# 9               Chinese Restaurant                       Rental Car Location
# 10                  Sandwich Place                                      Bank
# 11                  Sandwich Place                                  Gym Pool
# 12            Fast Food Restaurant                               Supermarket
# 13                  Sandwich Place                        Mexican Restaurant
# 14                           Hotel                       American Restaurant
# 15                             Bar                               Coffee Shop
# 16                        Pharmacy                Financial or Legal Service
# 17                 College Stadium                     General Entertainment
# 18                    Hockey Arena                      Fast Food Restaurant
# 19                            Park                                Theme Park
# 20                             Pub                         Convenience Store
# 21                           Trail                            Soccer Stadium
# 22   Vegetarian / Vegan Restaurant                               Art Gallery
# 23                             Bar                                 Bookstore
# 24                             Gym                                      Park
# 25                             Gym                                      Park
# 26                      Restaurant                       Japanese Restaurant
# 27                            Park               Eastern European Restaurant
# 28                   Grocery Store                               Pizza Place
# 29                            Bank                                  Pharmacy
# 30                            Park                Construction & Landscaping
# 31                            Park                         Convenience Store
# 32                     Pizza Place                                      Bank
# 33                Sculpture Garden                                      Café
# 34                   Shopping Mall                                      Café
# 35                        Bus Line                             Grocery Store
# 36                        Bus Stop                      Fast Food Restaurant
# 37                  Discount Store                                     Diner
# 38                             Gym                        Italian Restaurant
# 39                     Coffee Shop                                       Pub
# 40                           River                              Cupcake Shop
# 41                           River                              Cupcake Shop
# 42                     Coffee Shop                             Grocery Store
# 43                     Coffee Shop                             Grocery Store
# 44                Department Store                                      Park
# 45                   Grocery Store                               Pizza Place
# 46                Sushi Restaurant                                       Pub
# 47                            Café                               Pizza Place
# 48               Convenience Store                                    Bakery
# 49                  Discount Store                            Shipping Store
# 50                           Hotel                               Yoga Studio
# 51                     Pizza Place                               Coffee Shop
# 52                  Sandwich Place                          Greek Restaurant
# 53                  Breakfast Spot                         Convenience Store
# 54                  Breakfast Spot                         Convenience Store
# 55              Italian Restaurant                               Pizza Place
# 56            Fast Food Restaurant                                  Pharmacy
# 57            Fast Food Restaurant                               Coffee Shop
# 58                     Coffee Shop                               Pizza Place
# 59             Sporting Goods Shop                                     Trail
# 60                     Pizza Place                          Sushi Restaurant
# 61               Convenience Store                                      Bank
# 62                     Coffee Shop                                Beer Store
# 63                   Metro Station                                Playground
# 64             Japanese Restaurant                          Ramen Restaurant
# 65            Fast Food Restaurant                          Sushi Restaurant
# 66                 Thai Restaurant                               Coffee Shop
# 67                      Beer Store                            Sandwich Place
# 68                     Coffee Shop                               Pizza Place
# 69                            Café                                  Beer Bar
# 70   Vegetarian / Vegan Restaurant                        Mexican Restaurant
# 71                     Golf Course                             Smoothie Shop
# 72                            Café                               Coffee Shop
# 73              Tibetan Restaurant                             Grocery Store
# 74                     Bus Station                               Pizza Place
# 75              Chinese Restaurant                 Middle Eastern Restaurant
# 76              Chinese Restaurant                 Middle Eastern Restaurant
# 77                          Bakery                                      Café
# 78                     Coffee Shop                    Furniture / Home Store
# 79                           Hotel                             Big Box Store
# 80                           Diner                       Distribution Center
# 81                            Park                         Convenience Store
# 82                            Café                                  Beer Bar
# 83                          Bistro                             Grocery Store
# 84                     Pizza Place                                       Spa
# 85                Sushi Restaurant                                      Bank
# 86                     Pizza Place                            Breakfast Spot
# 87               Electronics Store                                  Dive Bar
# 88            Fast Food Restaurant                               Coffee Shop
# 89               Convenience Store                            Breakfast Spot
# 90                   Deli / Bodega                               Yoga Studio
# 91              Light Rail Station                                     Beach
# 92           Vietnamese Restaurant                               Coffee Shop
# 93                            Café                               Pizza Place
# 94                   Grocery Store                               Coffee Shop
# 95                   Grocery Store                               Coffee Shop
# 96          Furniture / Home Store                               Coffee Shop
# 97          Furniture / Home Store                               Coffee Shop
# 98                      Playground                         Electronics Store
# 99                            Park                               Pizza Place
# 100                      Gastropub                       Japanese Restaurant
# 101                        Theater                                     Hotel
# 102                           Café                                Restaurant
# 103                    Pizza Place                     Vietnamese Restaurant
# 104                           Café                       Japanese Restaurant
# 105                     Restaurant                      Gym / Fitness Center
# 106               Department Store             Paper / Office Supplies Store
# 107                    Pizza Place                             Deli / Bodega
# 108               Community Center                                     Hotel
# 109                    Coffee Shop                               Yoga Studio
# 110                 Sandwich Place                                Beer Store
# 111             Mexican Restaurant                            Sandwich Place
# 112                     Restaurant                               Pizza Place
# 113             Italian Restaurant                         French Restaurant
# 114           Cantonese Restaurant                                Food Court
# 115                    Pizza Place                                      Pool
# 116                     Playground                         Convenience Store
# 117                           Park                                     Trail
# 118                         Bakery                               Coffee Shop
# 119             Seafood Restaurant                                Restaurant
# 120                     Beer Store                               Coffee Shop
# 121                            Bar                                Restaurant
# 122                           Café                                  Beer Bar
# 123                           Park                                      Café
# 124                  Women's Store                        Mexican Restaurant
# 125                           Café                                  Beer Bar
# 126                  Grocery Store                               Yoga Studio
# 127                           Café                          Ramen Restaurant
# 128                           Park                                     Diner
# 129               Sushi Restaurant                              Burger Joint
# 130                    Pizza Place                         Convenience Store
# 131                 Sandwich Place                                  Gym Pool
# 132                     Restaurant                       American Restaurant
# 133             Italian Restaurant                                     Trail
# 134             Italian Restaurant                                      Café
# 135                           Park                            Discount Store
# 136              Convenience Store                         Electronics Store
# 137                    Coffee Shop                         Indian Restaurant
# 138                       Pharmacy                Financial or Legal Service
# 139                           Café                                  Bus Line
# 140                            Bar                                    Bakery
# 141                           Park                               Pizza Place
# 142                            Pub                                      Café
# 143                          Hotel                       Japanese Restaurant
# 144                           Bank                      Gym / Fitness Center
# 145                      Gastropub                                     Diner
# 146           Fast Food Restaurant                 Latin American Restaurant
# 147                    Coffee Shop                            Sandwich Place
# 148                          Hotel                               Yoga Studio
# 149                            Gym                                      Park
# 150                Thai Restaurant                       American Restaurant
# 151                         Bakery  Residential Building (Apartment / Condo)
# 152         Furniture / Home Store                         Electronics Store
# 153              Convenience Store                                    Bakery
# 154                          Trail                             Grocery Store
# 155                    Pizza Place                       American Restaurant
# 156                  Shopping Mall                                      Café
# 157               Department Store                             Grocery Store
# 158                   Dessert Shop                               Coffee Shop
# 159                   Skating Rink                              Intersection
# 160               Sushi Restaurant                               Pizza Place
# 161               Sushi Restaurant                                       Pub
# 162                           Park                            Sandwich Place
# 163                     Restaurant             Vegetarian / Vegan Restaurant
# 164                       Pharmacy                                      Park
# 165                 Discount Store                        Dim Sum Restaurant
# 166                 Breakfast Spot                         Convenience Store
# 167              Korean Restaurant                           Auto Dealership
# 168                    Coffee Shop                         Indian Restaurant
# 169                    Coffee Shop                        Chinese Restaurant
# 170                     Restaurant                                 Gastropub
# 171             Mexican Restaurant                                       Pub
# 172                    Yoga Studio                       Dumpling Restaurant
# 173                  Metro Station                                Playground
# 174                    Coffee Shop                               Flower Shop
# 175     Construction & Landscaping                                      Park
# 176                           Bank                             Grocery Store
# 177             Italian Restaurant                            Sandwich Place
# 178                Thai Restaurant                                Restaurant
# 179                          Hotel                                   Theater
# 180              French Restaurant                               Coffee Shop
# 181                           Bank                               Coffee Shop
# 182              Food & Drink Shop                                      Bank
# 183         Furniture / Home Store                                      Park
# 184                          Hotel                             Big Box Store
# 185              Electronics Store                                  Dive Bar
# 186                 Sandwich Place                             Grocery Store
# 187                      BBQ Joint                                   Dog Run
# 188                           Café                                  Beer Bar
# 189    Eastern European Restaurant                       Distribution Center
# 190              Convenience Store                            Breakfast Spot
# 191                 Sandwich Place                             Grocery Store
# 192                           Café                               Pizza Place
# 193                           Bank                            Ice Cream Shop
# 194                            Pub                          Sushi Restaurant
# 195                           Bank                         Afghan Restaurant
# 196                           Café                       Japanese Restaurant
# 197                       Boutique                               Coffee Shop
# 198                           Park                                     Trail
# 199      Middle Eastern Restaurant                     Portuguese Restaurant
# 200                         Bakery                                     Hotel
# 201                       Bus Stop                                 BBQ Joint
# 202                  Grocery Store                               Gas Station
# 203                           Café                               Coffee Shop
# 204                    Yoga Studio                       Dumpling Restaurant
# 205                           Park                         Convenience Store
# 206                      Gastropub                                      Bank
# 207                           Bank                            Ice Cream Shop
# 208                           Bank                            Ice Cream Shop
#
#              5th Most Common Venue          6th Most Common Venue  \
# 0                French Restaurant                   Dessert Shop
# 1               Frozen Yogurt Shop                      Juice Bar
# 2                     Camera Store  Paper / Office Supplies Store
# 3                    Grocery Store             Light Rail Station
# 4                  Thai Restaurant                           Bank
# 5                      Coffee Shop                    Pizza Place
# 6               Chinese Restaurant                           Bank
# 7                             Café                           Park
# 8                      Yoga Studio                            Gym
# 9                   Sandwich Place                 Discount Store
# 10                    Burger Joint                       Pharmacy
# 11                Sushi Restaurant                  Grocery Store
# 12                   Jewelry Store               Department Store
# 13                            Park              French Restaurant
# 14             Japanese Restaurant                            Gym
# 15                    Cocktail Bar              Indian Restaurant
# 16              Chinese Restaurant            Distribution Center
# 17                            Café                   Skating Rink
# 18                     Pizza Place                       Tea Room
# 19          Furniture / Home Store             Athletics & Sports
# 20                            Park                 Sandwich Place
# 21     Eastern European Restaurant                       Dive Bar
# 22                     Yoga Studio                 Cosmetics Shop
# 23                     Pizza Place  Vegetarian / Vegan Restaurant
# 24                         Brewery                 Scenic Lookout
# 25                         Brewery                 Scenic Lookout
# 26            Fast Food Restaurant      Middle Eastern Restaurant
# 27                        Dive Bar                Doctor's Office
# 28              Light Rail Station            Fried Chicken Joint
# 29                   Grocery Store                           Park
# 30                           River                    Yoga Studio
# 31                     Yoga Studio                       Dive Bar
# 32                  Sandwich Place                       Pharmacy
# 33                 Harbor / Marina               Airport Terminal
# 34                    Skating Rink                           Bank
# 35     Eastern European Restaurant                       Dive Bar
# 36                   Shopping Mall                     Beer Store
# 37                     Pizza Place      Middle Eastern Restaurant
# 38                             Bar                     Restaurant
# 39                     Yoga Studio                   Tennis Court
# 40                     Yoga Studio            Dumpling Restaurant
# 41                     Yoga Studio            Dumpling Restaurant
# 42               Electronics Store                  Shopping Mall
# 43               Electronics Store                  Shopping Mall
# 44                  Sandwich Place              Electronics Store
# 45                Toy / Game Store                  Big Box Store
# 46                          Bakery                           Bank
# 47                      Restaurant                     Beer Store
# 48     Eastern European Restaurant                       Dive Bar
# 49            Fast Food Restaurant                    Coffee Shop
# 50     Eastern European Restaurant                       Dive Bar
# 51                  Sandwich Place                           Bank
# 52                 Badminton Court              Food & Drink Shop
# 53                   Grocery Store                Thai Restaurant
# 54                   Grocery Store                Thai Restaurant
# 55                          Bakery           Fast Food Restaurant
# 56                    Tennis Court                 Sandwich Place
# 57                    Tennis Court              Convenience Store
# 58                  Sandwich Place              Convenience Store
# 59                       Pet Store                           Park
# 60                             Gym                     Restaurant
# 61                    Dessert Shop                          Trail
# 62               Convenience Store                           Café
# 63                             Spa                    Event Space
# 64                Sushi Restaurant             Italian Restaurant
# 65             Japanese Restaurant                    Pizza Place
# 66     Eastern European Restaurant             Italian Restaurant
# 67                   Train Station                      Pet Store
# 68                            Park                          Hotel
# 69             Japanese Restaurant                     Restaurant
# 70                  History Museum              French Restaurant
# 71                      Beer Store                  Grocery Store
# 72                     Pizza Place           Caribbean Restaurant
# 73     Eastern European Restaurant              Indian Restaurant
# 74                            Park                   Intersection
# 75                     Flea Market                    Supermarket
# 76                     Flea Market                    Supermarket
# 77                             Spa             Italian Restaurant
# 78                        Tea Room                            Gym
# ...
# 165         Cantonese Restaurant                     Restaurant
# 166                         Café             Italian Restaurant
# 167                   Smoke Shop                            Bar
# 168             Sushi Restaurant             Seafood Restaurant
# 169        Vietnamese Restaurant              Convenience Store
# 170          Japanese Restaurant                       Beer Bar
# 171                Metro Station             Athletics & Sports
# 172              Doctor's Office                        Dog Run
# 173          American Restaurant                    Yoga Studio
# 174                   Restaurant             Italian Restaurant
# 175              Doctor's Office                        Dog Run
# 176           Light Rail Station                   Burger Joint
# 177                 Burger Joint            Japanese Restaurant
# 178                         Café                 Breakfast Spot
# 179                Deli / Bodega            American Restaurant
# 180       Furniture / Home Store                 Ice Cream Shop
# 181               Sandwich Place                           Park
# 182              Doctor's Office                        Dog Run
# 183                    Drugstore                       Dive Bar
# 184           Seafood Restaurant                        Butcher
# 185             Doner Restaurant                     Donut Shop
# 186                     Pharmacy            Japanese Restaurant
# 187  Eastern European Restaurant                Doctor's Office
# 188          American Restaurant                        Theater
# 189                      Dog Run               Doner Restaurant
# 190                   Beer Store                           Café
# 191                  Pizza Place                      Bookstore
# 192                       Bakery              Health Food Store
# 193             Sushi Restaurant              Food & Drink Shop
# 194           Italian Restaurant              Mobile Phone Shop
# 195                     Pharmacy                    Supermarket
# 196           Seafood Restaurant            American Restaurant
# 197                         Café                           Park
# 198          Distribution Center                       Dive Bar
# 199                     Bus Line                   Intersection
# 200              Doctor's Office                        Dog Run
# 201          Japanese Restaurant             Mexican Restaurant
# 202       Thrift / Vintage Store                          Trail
# 203                  Supermarket                 Breakfast Spot
# 204              Doctor's Office                        Dog Run
# 205                  Yoga Studio    Eastern European Restaurant
# 206                  Gaming Cafe                         Bakery
# 207               Cosmetics Shop                    Supermarket
# 208               Cosmetics Shop                    Supermarket
#
#        9th Most Common Venue         10th Most Common Venue
# 0                 Restaurant                           Park
# 1              Movie Theater                     Restaurant
# 2          Food & Drink Shop                     Beer Store
# 3              Historic Site                Harbor / Marina
# 4                   Pharmacy            American Restaurant
# 5              Deli / Bodega                      Drugstore
# 6                   Bus Stop                    Frame Store
# 7                  Gastropub            Japanese Restaurant
# 8                   Beer Bar                    Art Gallery
# 9                 Beer Store               Storage Facility
# 10               Pizza Place                     Donut Shop
# 11                  Pharmacy                            Pub
# 12             Deli / Bodega                  Shopping Mall
# 13              Liquor Store      Middle Eastern Restaurant
# 14              Concert Hall                         Bakery
# 15       Japanese Restaurant                    Comedy Club
# 16                   Dog Run               Doner Restaurant
# 17       Distribution Center                       Dive Bar
# 18                     Hotel           Caribbean Restaurant
# 19     Performing Arts Venue                 Soccer Stadium
# 20             Metro Station               Sushi Restaurant
# 21          Doner Restaurant                     Donut Shop
# 22          Sushi Restaurant                     Restaurant
# 23            Sandwich Place            Japanese Restaurant
# 24                Steakhouse               Baseball Stadium
# 25                Steakhouse               Baseball Stadium
# 26            Sandwich Place             Chinese Restaurant
# 27                Donut Shop                      Drugstore
# 28                     Beach               Sushi Restaurant
# 29          Basketball Court         Furniture / Home Store
# 30           Doctor's Office                        Dog Run
# 31          Doner Restaurant                     Donut Shop
# 32            Discount Store                  Deli / Bodega
# 33        Airport Food Court             Light Rail Station
# 34                  Dive Bar                Doctor's Office
# 35          Doner Restaurant                     Donut Shop
# 36         Food & Drink Shop                 Sandwich Place
# 37                      Café                 Sandwich Place
# 38         French Restaurant                    Pizza Place
# 39        Italian Restaurant                    Event Space
# 40           Doctor's Office                        Dog Run
# 41           Doctor's Office                        Dog Run
# 42            Discount Store                 Sandwich Place
# 43            Discount Store                 Sandwich Place
# 44                Kids Store               Sushi Restaurant
# 45            Discount Store         Furniture / Home Store
# 46                 BBQ Joint             Frozen Yogurt Shop
# 47          Sushi Restaurant             Seafood Restaurant
# 48          Doner Restaurant                     Donut Shop
# 49                Donut Shop                  Deli / Bodega
# 50          Doner Restaurant                     Donut Shop
# 51                 Drugstore                       Dive Bar
# 52       Arts & Crafts Store               Storage Facility
# 53              Skating Rink                 Ice Cream Shop
# 54              Skating Rink                 Ice Cream Shop
# 55          Tapas Restaurant                           Bank
# 56               Supermarket                 Discount Store
# 57                 Drugstore                       Dive Bar
# 58       Distribution Center                       Dive Bar
# 59            Sandwich Place                    Bus Station
# 60      Fast Food Restaurant                            Bar
# 61        Chinese Restaurant                 Ice Cream Shop
# 62              Liquor Store                    Yoga Studio
# 63       Dumpling Restaurant                       Dive Bar
# 64        Mexican Restaurant                   Dance Studio
# 65             Movie Theater                  Deli / Bodega
# 66            Breakfast Spot            American Restaurant
# 67               Coffee Shop           Fast Food Restaurant
# 68                 Drugstore            Distribution Center
# 69                     Plaza         Furniture / Home Store
# 70                 BBQ Joint                     Donut Shop
# 71               Coffee Shop                           Café
# 72                 BBQ Joint                           Bank
# 73           Thai Restaurant                           Bank
# 74                Donut Shop            Distribution Center
# 75            Discount Store                           Café
# 76            Discount Store                           Café
# 77               Pizza Place                            Gym
# 78                    Bakery                           Bank
# 79            Sandwich Place                            Gym
# 80                Donut Shop                      Drugstore
# 81          Doner Restaurant                     Donut Shop
# 82                     Plaza         Furniture / Home Store
# 83         Indian Restaurant                 Sandwich Place
# 84              Dessert Shop                 Sandwich Place
# 85                      Café                   Dessert Shop
# 86       Distribution Center                       Dive Bar
# 87                 Drugstore            Dumpling Restaurant
# 88            Discount Store            Distribution Center
# 89           Thai Restaurant             Italian Restaurant
# 90          Doner Restaurant                     Donut Shop
# 91             Deli / Bodega                          Trail
# 92      Cantonese Restaurant                     Beer Store
# 93       Japanese Restaurant                            Bar
# 94     Vietnamese Restaurant                Thai Restaurant
# 95     Vietnamese Restaurant                Thai Restaurant
# 96           Thai Restaurant                  Moving Target
# 97           Thai Restaurant                  Moving Target
# 98           Doctor's Office                        Dog Run
# 99                       Bar                      BBQ Joint
# 100         Sushi Restaurant             Seafood Restaurant
# 101          Thai Restaurant                 Cosmetics Shop
# 102      American Restaurant                   Cocktail Bar
# 103              Supermarket       Mediterranean Restaurant
# 104         Ramen Restaurant                        Theater
# 105          Doctor's Office                        Dog Run
# 106     Fast Food Restaurant            Dumpling Restaurant
# 107               Donut Shop                      Drugstore
# 108                  Dog Run               Doner Restaurant
# 109         Doner Restaurant                     Donut Shop
# 110       Chinese Restaurant                     Bagel Shop
# 111               Restaurant              Convenience Store
# 112            Smoothie Shop                  Shopping Mall
# 113                      Spa            Japanese Restaurant
# 114              Gas Station                    Pizza Place
# 115             Dance Studio                     Print Shop
# 116         Doner Restaurant                     Donut Shop
# 117      Distribution Center                       Dive Bar
# 118                     Bank                 Sandwich Place
# 119                   Bakery                      Bookstore
# 120               Donut Shop                 Discount Store
# 121                   Bakery                  Grocery Store
# 122                    Plaza         Furniture / Home Store
# 123                 Aquarium                 Ice Cream Shop
# 124                      Gym            Dumpling Restaurant
# 125                    Plaza         Furniture / Home Store
# 126                  Dog Run               Doner Restaurant
# 127                      Bar                     Restaurant
# 128             Burger Joint      Latin American Restaurant
# 129          Bubble Tea Shop                   Liquor Store
# 130          Thai Restaurant                  Deli / Bodega
# 131                 Pharmacy                            Pub
# 132                    Hotel             Seafood Restaurant
# 133                    Diner               Sushi Restaurant
# 134         Toy / Game Store                          Diner
# 135              Coffee Shop                           Bank
# 136               Donut Shop                      Drugstore
# 137       Italian Restaurant                     Beer Store
# 138                  Dog Run               Doner Restaurant
# 139               Beer Store                         Bakery
# 140           Sandwich Place                     Restaurant
# 141          Doctor's Office                        Dog Run
# 142              Pizza Place                     Restaurant
# 143       Seafood Restaurant               Asian Restaurant
# 144                     Park                   Liquor Store
# 145         Ramen Restaurant                 Lingerie Store
# 146              Gas Station                 Ice Cream Shop
# 147            Burrito Place                      Pet Store
# 148               Donut Shop                      Drugstore
# 149               Steakhouse               Baseball Stadium
# 150             Amphitheater                        Dog Run
# 151                  Dog Run               Doner Restaurant
# 152                  Dog Run               Doner Restaurant
# 153         Doner Restaurant                     Donut Shop
# 154              Event Space            Distribution Center
# 155             Skating Rink                    Supermarket
# 156                 Dive Bar                Doctor's Office
# 157                     Farm                      Drugstore
# 158    Vietnamese Restaurant                    Record Shop
# 159                     Farm            Distribution Center
# 160             Skating Rink                         Bakery
# 161                BBQ Joint             Frozen Yogurt Shop
# 162           Discount Store                   Burger Joint
# 163       Italian Restaurant            Japanese Restaurant
# 164            Grocery Store                    Yoga Studio
# 165                Drugstore                       Dive Bar
# 166             Skating Rink                 Ice Cream Shop
# 167  Fruit & Vegetable Store                 Discount Store
# 168           Scenic Lookout                         Bakery
# 169                Gift Shop           Gym / Fitness Center
# 170                Bookstore             Italian Restaurant
# 171             Burger Joint                     Restaurant
# 172         Doner Restaurant                     Donut Shop
# 173      Dumpling Restaurant                       Dive Bar
# 174           Clothing Store                    Curling Ice
# 175         Doner Restaurant                     Donut Shop
# 176             Liquor Store                 Sandwich Place
# 177       Falafel Restaurant                  Burrito Place
# 178               Food Truck               Sushi Restaurant
# 179               Poke Place                          Plaza
# 180        Indian Restaurant  Vegetarian / Vegan Restaurant
# 181       Mexican Restaurant            Fried Chicken Joint
# 182         Doner Restaurant                     Donut Shop
# 183          Doctor's Office                        Dog Run
# 184           Sandwich Place                            Gym
# 185                Drugstore            Dumpling Restaurant
# 186           Breakfast Spot                    Men's Store
# 187         Doner Restaurant                     Donut Shop
# 188                    Plaza         Furniture / Home Store
# 189               Donut Shop                      Drugstore
# 190          Thai Restaurant             Italian Restaurant
# 191           Ice Cream Shop               Sushi Restaurant
# 192      Japanese Restaurant                            Bar
# 193              Gas Station                    Supermarket
# 194                   Bakery               Tapas Restaurant
# 195             Burger Joint                     Restaurant
# 196                  Theater                           Park
# 197                Bookstore                            Gym
# 198          Doctor's Office                        Dog Run
# 199      Distribution Center                       Dive Bar
# 200         Doner Restaurant                     Donut Shop
# 201              Pizza Place                    Coffee Shop
# 202               Laundromat                 Sandwich Place
# 203            Grocery Store      Middle Eastern Restaurant
# 204         Doner Restaurant                     Donut Shop
# 205          Doctor's Office                        Dog Run
# 206           Farmers Market                  Bowling Alley
# 207             Burger Joint                 Baseball Field
# 208             Burger Joint                 Baseball Field

# %% [markdown]
# ## 4. Results

# %% [markdown]
# The results from ranking show that Harbourfront, Lawrence Manor, Parkwoods, Regent Park and Victoria Village are the most similar neighborhoods to Yorkville, based on the most frequent venue category.
#
# The shortlist of similar venues are visualized in the map bellow.

# %% [markdown]
# #### Get top 10 Yorkville venues

# %%
# Create a ny_grouped copy
ny_grouped_top10 = ny_grouped.copy()

# Drop Neighborhood column
ny_grouped_top10.drop(labels='Neighborhood', axis=1, inplace=True)

# Sort columns by frequency
ny_grouped_top10 = ny_grouped_top10.sort_values(by=0, axis=1, ascending=False).iloc[:,:10]

# Reinsert Neighborhood column
ny_grouped_top10['Neighborhood'] = ny_venues['Neighborhood']

# Reorder columns to put Neighborhood in the first column
ny_grouped_top10_columns = [ny_grouped_top10.columns[-1]] + list(ny_grouped_top10.columns[:-1])
ny_grouped_top10_n = ny_grouped_top10[ny_grouped_top10_columns]
ny_grouped_top10_n
# Out:
#   Neighborhood  Coffee Shop  Ice Cream Shop  Pizza Place   Gym  \
# 0    Yorkville         0.07            0.04         0.04  0.04
#
#    Italian Restaurant  Deli / Bodega  Bagel Shop  Wine Shop   Bar  \
# 0                0.04           0.04        0.03       0.03  0.03
#
#    Mexican Restaurant
# 0                0.03

# %% [markdown]
# #### Get top 5 Toronto Neighborhoods

# %%
ny_grouped_top10_columns = ny_grouped_top10_n.drop(labels='Neighborhood', axis=1)

# Create a ny_grouped copy
toronto_grouped_intersection = toronto_grouped.copy()

# Drop Neighborhood column
toronto_grouped_intersection.drop(labels='Neighborhood', axis=1, inplace=True)

# Filter the same columns as the Top 10
toronto_grouped_intersection = toronto_grouped_intersection[ny_grouped_top10_columns.columns]

# Reinsert Neighborhood column
toronto_grouped_intersection['Neighborhood'] = toronto_venues['Neighborhood']

# Reorder columns to put Neighborhood in the first column
toronto_grouped_intersection_columns = [toronto_grouped_intersection.columns[-1]] + list(toronto_grouped_intersection.columns[:-1])
toronto_grouped_intersection = toronto_grouped_intersection[toronto_grouped_intersection_columns]

# Group column by Neighborhood
toronto_grouped_top = toronto_grouped_intersection.groupby('Neighborhood').mean().reset_index()
toronto_grouped_top
# Out:
#        Neighborhood  Coffee Shop  Ice Cream Shop  Pizza Place       Gym  \
# 0      Harbourfront     0.063075        0.005779     0.030619  0.009808
# 1    Lawrence Manor     0.065583        0.015518     0.031787  0.004697
# 2         Parkwoods     0.070725        0.018485     0.030372  0.015229
# 3       Regent Park     0.072782        0.007766     0.064346  0.008766
# 4  Victoria Village     0.054502        0.008497     0.069860  0.000000
#
#    Italian Restaurant  Deli / Bodega  Bagel Shop  Wine Shop       Bar  \
# 0            0.013503       0.009807    0.001723   0.000688  0.007991
# 1            0.019946       0.002273    0.000000   0.000000  0.007108
# 2            0.008921       0.006578    0.000000   0.000000  0.007644
# 3            0.016415       0.003538    0.002019   0.000000  0.007092
# 4            0.008497       0.011364    0.000000   0.000000  0.012529
#
#    Mexican Restaurant
# 0            0.010083
# 1            0.009367
# 2            0.005332
# 3            0.004394
# 4            0.000000

# %%
toronto_merged = toronto_grouped_top.copy()

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(tr_df.set_index('Neighborhood'), on='Neighborhood')
toronto_merged_columns = list(toronto_merged.columns[11:13]) + [toronto_merged.columns[0]] + list(toronto_merged.columns[13:15]) +  list(toronto_merged.columns[1:10])
toronto_merged = toronto_merged[toronto_merged_columns]

toronto_merged # check the last columns!
# Out:
#   PostalCode           Borough      Neighborhood   Latitude  Longitude  \
# 0        M5A  Downtown Toronto      Harbourfront  43.639510 -79.383160
# 1        M6A        North York    Lawrence Manor  43.722940 -79.431160
# 2        M3A        North York         Parkwoods  43.686575 -79.409993
# 3        M5A  Downtown Toronto       Regent Park  43.660690 -79.360310
# 4        M4A        North York  Victoria Village  43.731540 -79.314280
#
#    Coffee Shop  Ice Cream Shop  Pizza Place       Gym  Italian Restaurant  \
# 0     0.063075        0.005779     0.030619  0.009808            0.013503
# 1     0.065583        0.015518     0.031787  0.004697            0.019946
# 2     0.070725        0.018485     0.030372  0.015229            0.008921
# 3     0.072782        0.007766     0.064346  0.008766            0.016415
# 4     0.054502        0.008497     0.069860  0.000000            0.008497
#
#    Deli / Bodega  Bagel Shop  Wine Shop       Bar
# 0       0.009807    0.001723   0.000688  0.007991
# 1       0.002273    0.000000   0.000000  0.007108
# 2       0.006578    0.000000   0.000000  0.007644
# 3       0.003538    0.002019   0.000000  0.007092
# 4       0.011364    0.000000   0.000000  0.012529

# %% [markdown]
# #### Get coordinates of Toronto

# %%
address = 'Toronto, CA'

geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinates of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinates of Toronto are 43.6534817, -79.3839347.

# %% [markdown]
# #### Create a map to visualize the top 5 neighborhoods

# %%
# Create map
top_map = folium.Map(location=[latitude, longitude], zoom_start=11)

# Add markers to the map
markers_colors = []
for lat, lon, poi in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood']):
    label = folium.Popup(str(poi), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label).add_to(top_map)
       
top_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 5. Conclusion

# %% [markdown]
# In this case study, the input data set was scraped from different sources and was spatially enriched with information about access to different venues. It demonstrates how data science can be employed to one aspect of the real estate industry. Buying a home is a personal process, however a lot of decisions are heavily influenced by location. As shown in this study, Python libraries such as Pandas can be used for visualization and statistical analysis, and libraries such as the Foursquare API for Python for spatial analysis. The methods adopted in this study can be applied to any other real estate market to build other recommendation engines.

# %% [markdown]
# ## References

# %% [markdown]
# [1] https://geo.nyu.edu/catalog/nyu_2451_34572
#
# [2] https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M

# %% [markdown]
# ---
#
# <h4>Author:  <a href="https://br.linkedin.com/in/henrique-mand">Henrique Mandt</a></h4>
# <p><a href="https://br.linkedin.com/in/henrique-mand">Henrique Mandt</a>, Civil Engineer and Consultant with a track record of developing soluctions that substantially increases operational efficiency, mitigate risks and maximize benefits for teams, investors and customers. He is a Data Scientist enthusiast with interest in data mining, machine learning and spatial statistical modelling.</p>
#
# ---
